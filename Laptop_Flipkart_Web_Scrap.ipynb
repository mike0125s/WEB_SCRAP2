# %%
import requests
from bs4 import BeautifulSoup
import csv 
import pandas as pd


descriptions = []
processors = []
ram = []
os=[]
storage = []
inches = []
warranty = []
prices = []
ratings = []


pages = list(range(1,10))
for page in pages:
  req = requests.get("https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}".format(page)).text  # URL of the website which you want to scrape
 
  soup = BeautifulSoup(req,'html.parser')
  

  desc = soup.find_all('div' , class_='_4rR01T')
  for i in range(len(desc)):
      descriptions.append(desc[i].text)
  len(descriptions)

  commonclass = soup.find_all('li',class_='rgWa7D') 
  for i in range(0,len(commonclass)):
    p=commonclass[i].text 
    if("Core" in p): 
        processors.append(p)
    elif("RAM" in p): 
        ram.append(p)
    elif("HDD" in p or "SSD" in p):
        storage.append(p)
    elif("Operating" in p):
        os.append(p)
    elif("Display" in p):
        inches.append(p)
    elif("Warranty" in p):
        warranty.append(p)

  price = soup.find_all('div',class_='_30jeq3 _1_WHN1') 
  
  for i in range(len(price)):
    prices.append(price[i].text)
    len(prices)

  rating = soup.find_all('div',class_='_3LWZlK') 
 
  for i in range(len(rating)):
    ratings.append(rating[i].text)
    len(ratings)
print(len(descriptions))
print(len(processors))
print(len(ram))
print(len(os))
print(len(storage))
print(len(warranty))
print(len(inches))
print(len(prices))
print(len(ratings))
# Out:
# 216
# 210
# 216
# 216
# 216
# 199
# 220
# 216
# 323

# %%
df = {'Description':descriptions[199],'Processor':processors[199],'RAM':ram[199],'Operating System':os[slice(199)],'Storage':storage[slice(199)],'Display':inches[slice(199)],'Warranty':warranty[slice(199)],'Price':prices[slice(199)]}
dataset = pd.DataFrame(data = df)

# %%
dataset
# Out:
#                                            Description  \
# 0    ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 1    ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 2    ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 3    ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 4    ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# ..                                                 ...
# 194  ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 195  ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 196  ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 197  ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 198  ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
#
#                            Processor             RAM  \
# 0    AMD Ryzen 5 Hexa Core Processor  16 GB DDR4 RAM
# 1    AMD Ryzen 5 Hexa Core Processor  16 GB DDR4 RAM
# 2    AMD Ryzen 5 Hexa Core Processor  16 GB DDR4 RAM
# 3    AMD Ryzen 5 Hexa Core Processor  16 GB DDR4 RAM
# ...

# %%
dataset.to_csv('laptops20.csv')
